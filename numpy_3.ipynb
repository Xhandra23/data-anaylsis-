# %% [markdown]
# <a href="https://colab.research.google.com/github/Xhandra23/data-anaylsis-/blob/main/numpy_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([10,20,30,40,50,60])
arr=np.insert(arr,2,[3,4])
print(arr)
# Out:
# [10 20  3  4 30 40 50 60]

# %%
import numpy as np
arr  = np.array([[2,3,4],[4,5,6]])
arr = np.insert(arr,2,[4,5,9],axis=0)
print(arr)
print(np.delete(arr,2,axis=0))
print(arr)
# Out:
# [[2 3 4]
#  [4 5 6]
#  [4 5 9]]
# [[2 3 4]
#  [4 5 6]]
# [[2 3 4]
#  [4 5 6]
#  [4 5 9]]

# %%
import numpy as np
arr = np.array([10,20,30,40,50,60])
arr=np.delete(arr,(3,4))
print(arr)
# Out:
# [10 20 30 60]

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[2,9,4,5,2]])
print(np.sum(arr,axis=1))
print(np.sum(arr,axis=0))
# Out:
# [19 22]
# [ 4 12  8 10  7]

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[2,9,4,5,2]])
print(np.max(arr))
# Out:
# 9

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[2,9,4,5,2]])
print(np.min(arr))
# Out:
# 2

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[2,9,4,5,2]])
print(np.var(arr))
# Out:
# 4.090000000000001

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[2,9,4,5,2]])
print(np.mean(arr))
# Out:
# 4.1

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[2,9,4,5,2]])
print(np.std(arr))
# Out:
# 2.022374841615669

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[2,9,4,5,2]])
print(np.percentile(arr,[30,80 ,45,100]))
# Out:
# [2.7 5.  4.  9. ]

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[2,9,4,5,2]])
print(np.quantile(arr,1))
# Out:
# 9

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[3,2,9,4,5]])
print(np.argmax(arr))
# Out:
# 7

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[2,9,4,5,2]])
print(np.argmin(arr))
# Out:
# 0

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[2,9,4,5,2]])
print(np.log10(arr))
print(np.log2(arr))
# Out:
# [[0.30103    0.47712125 0.60205999 0.69897    0.69897   ]
#  [0.30103    0.95424251 0.60205999 0.69897    0.30103   ]]
# [[1.         1.5849625  2.         2.32192809 2.32192809]
#  [1.         3.169925   2.         2.32192809 1.        ]]

# %%
import numpy as np
arr = np.array([[2,3,4,5,5],[2,9,4,5,2]])
print(np.sqrt(arr))
# Out:
# [[1.41421356 1.73205081 2.         2.23606798 2.23606798]
#  [1.41421356 3.         2.         2.23606798 1.41421356]]

# %%
import numpy as np
arr = np.array([2.3,3.56,4.89,5.90,5.78])
print(np.round(arr))
print(np.round(arr,2))
# Out:
# [2. 4. 5. 6. 6.]
# [2.3  3.56 4.89 5.9  5.78]

# %%
import numpy as np
arr = np.array([2.3,3.56,4.89,5.90,5.78])
print(np.floor(arr))
# Out:
# [2. 3. 4. 5. 5.]

# %%
import numpy as np
arr = np.array([2.3,3.56,4.89,5.90,5.78])
print(np.ceil(arr))
# Out:
# [3. 4. 5. 6. 6.]

# %%
import numpy as np
arr = np.array([-2.3,3.56,4.89,-5.90,5.78])
print(np.abs(arr))
# Out:
# [5.78 5.9  4.89 3.56 2.3 ]

# %%
import numpy as np
arr = np.array([-2.3,3.56,4.89,-5.90,5.78])
print(np.sort(arr))
# Out:
# [-5.9  -2.3   3.56  4.89  5.78]
