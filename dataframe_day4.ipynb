# %% [markdown]
# <a href="https://colab.research.google.com/github/Xhandra23/data-anaylsis-/blob/main/dataframe_day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' merging dataframes'''
import pandas as pd
df1=pd.DataFrame({
    'id'  :[1,23,4,5,2],
    'name' :["son",'chan','mega','mali','sai']

})
#print(df1)

df2 = pd.DataFrame({
    'id':[1,2,3,4,5],
    'name':['ravi','suma','maaa','muh','goat']

})
#print(df2)


#mg = pd.merge(df1,df2,on='id',how='outer')
#print(mg)

''' pd.concat()'''
#com = pd.concat([df1,df2],axis=0,ignore_index=True)
com = pd.concat([df1,df2],axis=1)
print(com)
# Out:
#    id  name  id  name
# 0   1   son   1  ravi
# 1  23  chan   2  suma
# 2   4  mega   3  maaa
# 3   5  mali   4   muh
# 4   2   sai   5  goat

# %%
import pandas as pd
df = pd.read_csv('employee_dataset_1000_records.csv')
print(df)

em = pd.read_excel('/content/employee_dataset_1000_records.xlsx')
print(em)

am = pd.read_json('/content/employees.json')
print(am)
# Out:
#      Employee_ID        Name   Age  Department           City   Salary  \
# 0           1001  Employee_1  59.0  Operations          Delhi  80539.0
# 1           1002  Employee_2  49.0          IT         Mumbai  84077.0
# 2           1003  Employee_3  35.0  Operations  Visakhapatnam  39817.0
# 3           1004  Employee_4  28.0     Finance          Delhi  55861.0
# 4           1005  Employee_5  41.0         NaN          Delhi  31428.0
# ..           ...         ...   ...         ...            ...      ...
# 995         1001  Employee_1  59.0  Operations          Delhi  80539.0
# 996         1002  Employee_2  49.0          IT         Mumbai  84077.0
# 997         1003  Employee_3  35.0  Operations  Visakhapatnam  39817.0
# 998         1004  Employee_4  28.0     Finance          Delhi  55861.0
# 999         1005  Employee_5  41.0         NaN          Delhi  31428.0
#
#      Experience_Years  Performance_Score Joining_Date                  Email  \
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/employee_dataset_1000_records.csv')
#print(df)
df.head(23)
df.tail(8)

df.isna().sum()
# Out:
# Employee_ID            0
# Name                   0
# Age                   30
# Department           138
# City                 139
# Salary                25
# Experience_Years      20
# Performance_Score    183
# Joining_Date          35
# Email                 19
# Phone                 15
# Projects              26
# Working_Hours         31
# Remote_Work          320
# Bonus                 26
# dtype: int64

# %%
import pandas as pandas
df = pd.read_excel('/content/Sample - Superstore.xls')

'''df.info()
df.head(10)
df.tail(10)
df.columns
ed = df[['Category','Sales']]

print(ed)
df.loc[df["Sales"] > 500, "Sales"]
df[df["Profit"] > 100]

print(df[df["Region"] == "West"])
df[(df["Quantity"] > 5) | (df["Sales"] > 500)]'''
df.loc[10:19]
df[["Customer Name","Category","Sales","Profit"]]

df.loc[[0,5,10,15,20]]

df.loc[20:30]

df.rename(columns={"Sales":"Sales_Amount","Profit": "Profit_amount", "Quantity":"Quantity_Sold","Category"  : "Product_category"},inplace=True)
print(df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Product_category',
#        'Sub-Category', 'Product Name', 'Sales_Amount', 'Quantity_Sold',
#        'Discount', 'Profit_amount'],
#       dtype='object')
